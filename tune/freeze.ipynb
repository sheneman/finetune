# %% [markdown]
# <a href="https://colab.research.google.com/github/sheneman/finetune/blob/main/tune/freeze.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# freeze.py
#
# An example of Parameter Efficient Fine Tuning
#
# Load GPT-2 from HuggingFace
# ----------------------------
#   1. Print the layers of the model
#   2. Freeze the first 3/4 transformer blocks of the model prior to fine-tuning
#   3. Print the layers of the model (again, now woth frozen transformer blocks)
#
# Luke Sheneman
# Research Computing and Data Services (RCDS)
# Institute for Interdisciplinary Data Sciences (IIDS)
#
# sheneman@uidaho.edu
# 2024
#

# %%
import torch
from transformers import GPT2LMHeadModel

# %%
# Load pre-trained GPT-2 model
model = GPT2LMHeadModel.from_pretrained("gpt2")
# Out:
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/utils/_token.py:88: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# config.json:   0%|          | 0.00/665 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/548M [00:00<?, ?B/s]
# generation_config.json:   0%|          | 0.00/124 [00:00<?, ?B/s]

# %%
params = model.parameters()

# Access the individual layers (modules) of the model
model_layers = list(model.children())

# let's print a condensed version of the model, starting with the first layer
first_layer = model_layers[0]
print("\n")
print("Condensed representation of GPT-2 Architecture:")
print("\n\n")
print(first_layer)
print("\n\n")
# Out:
# Condensed representation of GPT-2 Architecture:
#
#
#
# GPT2Model(
#   (wte): Embedding(50257, 768)
#   (wpe): Embedding(1024, 768)
#   (drop): Dropout(p=0.1, inplace=False)
#   (h): ModuleList(
#     (0-11): 12 x GPT2Block(
#       (ln_1): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#       (attn): GPT2Attention(
#         (c_attn): Conv1D()
#         (c_proj): Conv1D()
#         (attn_dropout): Dropout(p=0.1, inplace=False)
#         (resid_dropout): Dropout(p=0.1, inplace=False)
#       )
#       (ln_2): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#       (mlp): GPT2MLP(
#         (c_fc): Conv1D()
#         (c_proj): Conv1D()
#         (act): NewGELUActivation()
#         (dropout): Dropout(p=0.1, inplace=False)
#       )
#     )
#   )
#   (ln_f): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
# )

# %%
# Print the layers of the model
print("\n\n*******************************")
print("ORIGINAL MODEL:")
print("NUMBER OF TRANSFORMER BLOCKS: ", len(model.transformer.h))
print("NUMBER OF TRAINABLE PARAMETERS: ", sum(p.numel() for p in params if p.requires_grad))
print("*******************************\n")
for idx, (name, param) in enumerate(model.named_parameters()):
	print(f"Layer {idx}: {name}, Frozen: {not param.requires_grad}")
# Out:
# *******************************
# ORIGINAL MODEL:
# NUMBER OF TRANSFORMER BLOCKS:  12
# NUMBER OF TRAINABLE PARAMETERS:  124439808
# *******************************
#
# Layer 0: transformer.wte.weight, Frozen: False
# Layer 1: transformer.wpe.weight, Frozen: False
# Layer 2: transformer.h.0.ln_1.weight, Frozen: False
# Layer 3: transformer.h.0.ln_1.bias, Frozen: False
# Layer 4: transformer.h.0.attn.c_attn.weight, Frozen: False
# Layer 5: transformer.h.0.attn.c_attn.bias, Frozen: False
# Layer 6: transformer.h.0.attn.c_proj.weight, Frozen: False
# Layer 7: transformer.h.0.attn.c_proj.bias, Frozen: False
# Layer 8: transformer.h.0.ln_2.weight, Frozen: False
# Layer 9: transformer.h.0.ln_2.bias, Frozen: False
# Layer 10: transformer.h.0.mlp.c_fc.weight, Frozen: False
# Layer 11: transformer.h.0.mlp.c_fc.bias, Frozen: False
# Layer 12: transformer.h.0.mlp.c_proj.weight, Frozen: False
# Layer 13: transformer.h.0.mlp.c_proj.bias, Frozen: False
# Layer 14: transformer.h.1.ln_1.weight, Frozen: False
# Layer 15: transformer.h.1.ln_1.bias, Frozen: False
# Layer 16: transformer.h.1.attn.c_attn.weight, Frozen: False
# Layer 17: transformer.h.1.attn.c_attn.bias, Frozen: False
# Layer 18: transformer.h.1.attn.c_proj.weight, Frozen: False
# Layer 19: transformer.h.1.attn.c_proj.bias, Frozen: False
# Layer 20: transformer.h.1.ln_2.weight, Frozen: False
# Layer 21: transformer.h.1.ln_2.bias, Frozen: False
# Layer 22: transformer.h.1.mlp.c_fc.weight, Frozen: False
# Layer 23: transformer.h.1.mlp.c_fc.bias, Frozen: False
# Layer 24: transformer.h.1.mlp.c_proj.weight, Frozen: False
# Layer 25: transformer.h.1.mlp.c_proj.bias, Frozen: False
# Layer 26: transformer.h.2.ln_1.weight, Frozen: False
# Layer 27: transformer.h.2.ln_1.bias, Frozen: False
# Layer 28: transformer.h.2.attn.c_attn.weight, Frozen: False
# Layer 29: transformer.h.2.attn.c_attn.bias, Frozen: False
# Layer 30: transformer.h.2.attn.c_proj.weight, Frozen: False
# Layer 31: transformer.h.2.attn.c_proj.bias, Frozen: False
# Layer 32: transformer.h.2.ln_2.weight, Frozen: False
# Layer 33: transformer.h.2.ln_2.bias, Frozen: False
# Layer 34: transformer.h.2.mlp.c_fc.weight, Frozen: False
# Layer 35: transformer.h.2.mlp.c_fc.bias, Frozen: False
# Layer 36: transformer.h.2.mlp.c_proj.weight, Frozen: False
# Layer 37: transformer.h.2.mlp.c_proj.bias, Frozen: False
# Layer 38: transformer.h.3.ln_1.weight, Frozen: False
# Layer 39: transformer.h.3.ln_1.bias, Frozen: False
# Layer 40: transformer.h.3.attn.c_attn.weight, Frozen: False
# Layer 41: transformer.h.3.attn.c_attn.bias, Frozen: False
# Layer 42: transformer.h.3.attn.c_proj.weight, Frozen: False
# Layer 43: transformer.h.3.attn.c_proj.bias, Frozen: False
# Layer 44: transformer.h.3.ln_2.weight, Frozen: False
# Layer 45: transformer.h.3.ln_2.bias, Frozen: False
# Layer 46: transformer.h.3.mlp.c_fc.weight, Frozen: False
# Layer 47: transformer.h.3.mlp.c_fc.bias, Frozen: False
# Layer 48: transformer.h.3.mlp.c_proj.weight, Frozen: False
# Layer 49: transformer.h.3.mlp.c_proj.bias, Frozen: False
# Layer 50: transformer.h.4.ln_1.weight, Frozen: False
# Layer 51: transformer.h.4.ln_1.bias, Frozen: False
# Layer 52: transformer.h.4.attn.c_attn.weight, Frozen: False
# Layer 53: transformer.h.4.attn.c_attn.bias, Frozen: False
# Layer 54: transformer.h.4.attn.c_proj.weight, Frozen: False
# Layer 55: transformer.h.4.attn.c_proj.bias, Frozen: False
# Layer 56: transformer.h.4.ln_2.weight, Frozen: False
# Layer 57: transformer.h.4.ln_2.bias, Frozen: False
# Layer 58: transformer.h.4.mlp.c_fc.weight, Frozen: False
# Layer 59: transformer.h.4.mlp.c_fc.bias, Frozen: False
# Layer 60: transformer.h.4.mlp.c_proj.weight, Frozen: False
# Layer 61: transformer.h.4.mlp.c_proj.bias, Frozen: False
# Layer 62: transformer.h.5.ln_1.weight, Frozen: False
# Layer 63: transformer.h.5.ln_1.bias, Frozen: False
# Layer 64: transformer.h.5.attn.c_attn.weight, Frozen: False
# Layer 65: transformer.h.5.attn.c_attn.bias, Frozen: False
# Layer 66: transformer.h.5.attn.c_proj.weight, Frozen: False
# Layer 67: transformer.h.5.attn.c_proj.bias, Frozen: False
# Layer 68: transformer.h.5.ln_2.weight, Frozen: False
# Layer 69: transformer.h.5.ln_2.bias, Frozen: False
# Layer 70: transformer.h.5.mlp.c_fc.weight, Frozen: False
# Layer 71: transformer.h.5.mlp.c_fc.bias, Frozen: False
# Layer 72: transformer.h.5.mlp.c_proj.weight, Frozen: False
# Layer 73: transformer.h.5.mlp.c_proj.bias, Frozen: False
# Layer 74: transformer.h.6.ln_1.weight, Frozen: False
# Layer 75: transformer.h.6.ln_1.bias, Frozen: False
# Layer 76: transformer.h.6.attn.c_attn.weight, Frozen: False
# Layer 77: transformer.h.6.attn.c_attn.bias, Frozen: False
# Layer 78: transformer.h.6.attn.c_proj.weight, Frozen: False
# Layer 79: transformer.h.6.attn.c_proj.bias, Frozen: False
# Layer 80: transformer.h.6.ln_2.weight, Frozen: False
# Layer 81: transformer.h.6.ln_2.bias, Frozen: False
# Layer 82: transformer.h.6.mlp.c_fc.weight, Frozen: False
# Layer 83: transformer.h.6.mlp.c_fc.bias, Frozen: False
# Layer 84: transformer.h.6.mlp.c_proj.weight, Frozen: False
# Layer 85: transformer.h.6.mlp.c_proj.bias, Frozen: False
# Layer 86: transformer.h.7.ln_1.weight, Frozen: False
# Layer 87: transformer.h.7.ln_1.bias, Frozen: False
# Layer 88: transformer.h.7.attn.c_attn.weight, Frozen: False
# Layer 89: transformer.h.7.attn.c_attn.bias, Frozen: False
# Layer 90: transformer.h.7.attn.c_proj.weight, Frozen: False
# Layer 91: transformer.h.7.attn.c_proj.bias, Frozen: False
# Layer 92: transformer.h.7.ln_2.weight, Frozen: False
# Layer 93: transformer.h.7.ln_2.bias, Frozen: False
# Layer 94: transformer.h.7.mlp.c_fc.weight, Frozen: False
# Layer 95: transformer.h.7.mlp.c_fc.bias, Frozen: False
# Layer 96: transformer.h.7.mlp.c_proj.weight, Frozen: False
# Layer 97: transformer.h.7.mlp.c_proj.bias, Frozen: False
# Layer 98: transformer.h.8.ln_1.weight, Frozen: False
# Layer 99: transformer.h.8.ln_1.bias, Frozen: False
# Layer 100: transformer.h.8.attn.c_attn.weight, Frozen: False
# Layer 101: transformer.h.8.attn.c_attn.bias, Frozen: False
# Layer 102: transformer.h.8.attn.c_proj.weight, Frozen: False
# Layer 103: transformer.h.8.attn.c_proj.bias, Frozen: False
# Layer 104: transformer.h.8.ln_2.weight, Frozen: False
# Layer 105: transformer.h.8.ln_2.bias, Frozen: False
# Layer 106: transformer.h.8.mlp.c_fc.weight, Frozen: False
# Layer 107: transformer.h.8.mlp.c_fc.bias, Frozen: False
# Layer 108: transformer.h.8.mlp.c_proj.weight, Frozen: False
# Layer 109: transformer.h.8.mlp.c_proj.bias, Frozen: False
# Layer 110: transformer.h.9.ln_1.weight, Frozen: False
# Layer 111: transformer.h.9.ln_1.bias, Frozen: False
# Layer 112: transformer.h.9.attn.c_attn.weight, Frozen: False
# Layer 113: transformer.h.9.attn.c_attn.bias, Frozen: False
# Layer 114: transformer.h.9.attn.c_proj.weight, Frozen: False
# Layer 115: transformer.h.9.attn.c_proj.bias, Frozen: False
# Layer 116: transformer.h.9.ln_2.weight, Frozen: False
# Layer 117: transformer.h.9.ln_2.bias, Frozen: False
# Layer 118: transformer.h.9.mlp.c_fc.weight, Frozen: False
# Layer 119: transformer.h.9.mlp.c_fc.bias, Frozen: False
# Layer 120: transformer.h.9.mlp.c_proj.weight, Frozen: False
# Layer 121: transformer.h.9.mlp.c_proj.bias, Frozen: False
# Layer 122: transformer.h.10.ln_1.weight, Frozen: False
# Layer 123: transformer.h.10.ln_1.bias, Frozen: False
# Layer 124: transformer.h.10.attn.c_attn.weight, Frozen: False
# Layer 125: transformer.h.10.attn.c_attn.bias, Frozen: False
# Layer 126: transformer.h.10.attn.c_proj.weight, Frozen: False
# Layer 127: transformer.h.10.attn.c_proj.bias, Frozen: False
# Layer 128: transformer.h.10.ln_2.weight, Frozen: False
# Layer 129: transformer.h.10.ln_2.bias, Frozen: False
# Layer 130: transformer.h.10.mlp.c_fc.weight, Frozen: False
# Layer 131: transformer.h.10.mlp.c_fc.bias, Frozen: False
# Layer 132: transformer.h.10.mlp.c_proj.weight, Frozen: False
# Layer 133: transformer.h.10.mlp.c_proj.bias, Frozen: False
# Layer 134: transformer.h.11.ln_1.weight, Frozen: False
# Layer 135: transformer.h.11.ln_1.bias, Frozen: False
# Layer 136: transformer.h.11.attn.c_attn.weight, Frozen: False
# Layer 137: transformer.h.11.attn.c_attn.bias, Frozen: False
# Layer 138: transformer.h.11.attn.c_proj.weight, Frozen: False
# Layer 139: transformer.h.11.attn.c_proj.bias, Frozen: False
# Layer 140: transformer.h.11.ln_2.weight, Frozen: False
# Layer 141: transformer.h.11.ln_2.bias, Frozen: False
# Layer 142: transformer.h.11.mlp.c_fc.weight, Frozen: False
# Layer 143: transformer.h.11.mlp.c_fc.bias, Frozen: False
# Layer 144: transformer.h.11.mlp.c_proj.weight, Frozen: False
# Layer 145: transformer.h.11.mlp.c_proj.bias, Frozen: False
# Layer 146: transformer.ln_f.weight, Frozen: False
# Layer 147: transformer.ln_f.bias, Frozen: False

# %%
print("\n\n*******************************")
print("FREEZING MODEL FOR FINE-TUNING")
print("*******************************\n")


# Freeze the first 5/6 of the transformer blocks
num_layers = len(model.transformer.h)  # Total number of transformer blocks
num_layers_to_freeze = 5 * num_layers // 6  # Calculate 5/6 of the total

for layer in model.transformer.h[:num_layers_to_freeze]:
	for param in layer.parameters():
		param.requires_grad = False
# Out:
# *******************************
# FREEZING MODEL FOR FINE-TUNING
# *******************************

# %%
#
# Here, let's explicitly freeze the token embedding layer
#
# Find the "wte" layer
wte_layer = None
for layer_name, layer in model.named_modules():
	if "wte" in layer_name:
		wte_layer = layer
		break

# Check if the "wte" layer was found
if wte_layer is not None:
	# Freeze the "wte" layer by setting requires_grad to False for its parameters
	for param in wte_layer.parameters():
		param.requires_grad = False

# %%
params = model.parameters()

# Print which layers are frozen and which are not
print("\n\n*******************************")
print("FROZEN MODEL:")
print("NUMBER OF TRANSFORMER BLOCKS: ", len(model.transformer.h))
print("NUMBER OF TRAINABLE PARAMETERS: ", sum(p.numel() for p in params if p.requires_grad))
print("*******************************\n")
for idx, (name, param) in enumerate(model.named_parameters()):
	print(f"Layer {idx}: {name}, Frozen: {not param.requires_grad}")
# Out:
# *******************************
# FROZEN MODEL:
# NUMBER OF TRANSFORMER BLOCKS:  12
# NUMBER OF TRAINABLE PARAMETERS:  14963712
# *******************************
#
# Layer 0: transformer.wte.weight, Frozen: True
# Layer 1: transformer.wpe.weight, Frozen: False
# Layer 2: transformer.h.0.ln_1.weight, Frozen: True
# Layer 3: transformer.h.0.ln_1.bias, Frozen: True
# Layer 4: transformer.h.0.attn.c_attn.weight, Frozen: True
# Layer 5: transformer.h.0.attn.c_attn.bias, Frozen: True
# Layer 6: transformer.h.0.attn.c_proj.weight, Frozen: True
# Layer 7: transformer.h.0.attn.c_proj.bias, Frozen: True
# Layer 8: transformer.h.0.ln_2.weight, Frozen: True
# Layer 9: transformer.h.0.ln_2.bias, Frozen: True
# Layer 10: transformer.h.0.mlp.c_fc.weight, Frozen: True
# Layer 11: transformer.h.0.mlp.c_fc.bias, Frozen: True
# Layer 12: transformer.h.0.mlp.c_proj.weight, Frozen: True
# Layer 13: transformer.h.0.mlp.c_proj.bias, Frozen: True
# Layer 14: transformer.h.1.ln_1.weight, Frozen: True
# Layer 15: transformer.h.1.ln_1.bias, Frozen: True
# Layer 16: transformer.h.1.attn.c_attn.weight, Frozen: True
# Layer 17: transformer.h.1.attn.c_attn.bias, Frozen: True
# Layer 18: transformer.h.1.attn.c_proj.weight, Frozen: True
# Layer 19: transformer.h.1.attn.c_proj.bias, Frozen: True
# Layer 20: transformer.h.1.ln_2.weight, Frozen: True
# Layer 21: transformer.h.1.ln_2.bias, Frozen: True
# Layer 22: transformer.h.1.mlp.c_fc.weight, Frozen: True
# Layer 23: transformer.h.1.mlp.c_fc.bias, Frozen: True
# Layer 24: transformer.h.1.mlp.c_proj.weight, Frozen: True
# Layer 25: transformer.h.1.mlp.c_proj.bias, Frozen: True
# Layer 26: transformer.h.2.ln_1.weight, Frozen: True
# Layer 27: transformer.h.2.ln_1.bias, Frozen: True
# Layer 28: transformer.h.2.attn.c_attn.weight, Frozen: True
# Layer 29: transformer.h.2.attn.c_attn.bias, Frozen: True
# Layer 30: transformer.h.2.attn.c_proj.weight, Frozen: True
# Layer 31: transformer.h.2.attn.c_proj.bias, Frozen: True
# Layer 32: transformer.h.2.ln_2.weight, Frozen: True
# Layer 33: transformer.h.2.ln_2.bias, Frozen: True
# Layer 34: transformer.h.2.mlp.c_fc.weight, Frozen: True
# Layer 35: transformer.h.2.mlp.c_fc.bias, Frozen: True
# Layer 36: transformer.h.2.mlp.c_proj.weight, Frozen: True
# Layer 37: transformer.h.2.mlp.c_proj.bias, Frozen: True
# Layer 38: transformer.h.3.ln_1.weight, Frozen: True
# Layer 39: transformer.h.3.ln_1.bias, Frozen: True
# Layer 40: transformer.h.3.attn.c_attn.weight, Frozen: True
# Layer 41: transformer.h.3.attn.c_attn.bias, Frozen: True
# Layer 42: transformer.h.3.attn.c_proj.weight, Frozen: True
# Layer 43: transformer.h.3.attn.c_proj.bias, Frozen: True
# Layer 44: transformer.h.3.ln_2.weight, Frozen: True
# Layer 45: transformer.h.3.ln_2.bias, Frozen: True
# Layer 46: transformer.h.3.mlp.c_fc.weight, Frozen: True
# Layer 47: transformer.h.3.mlp.c_fc.bias, Frozen: True
# Layer 48: transformer.h.3.mlp.c_proj.weight, Frozen: True
# Layer 49: transformer.h.3.mlp.c_proj.bias, Frozen: True
# Layer 50: transformer.h.4.ln_1.weight, Frozen: True
# Layer 51: transformer.h.4.ln_1.bias, Frozen: True
# Layer 52: transformer.h.4.attn.c_attn.weight, Frozen: True
# Layer 53: transformer.h.4.attn.c_attn.bias, Frozen: True
# Layer 54: transformer.h.4.attn.c_proj.weight, Frozen: True
# Layer 55: transformer.h.4.attn.c_proj.bias, Frozen: True
# Layer 56: transformer.h.4.ln_2.weight, Frozen: True
# Layer 57: transformer.h.4.ln_2.bias, Frozen: True
# Layer 58: transformer.h.4.mlp.c_fc.weight, Frozen: True
# Layer 59: transformer.h.4.mlp.c_fc.bias, Frozen: True
# Layer 60: transformer.h.4.mlp.c_proj.weight, Frozen: True
# Layer 61: transformer.h.4.mlp.c_proj.bias, Frozen: True
# Layer 62: transformer.h.5.ln_1.weight, Frozen: True
# Layer 63: transformer.h.5.ln_1.bias, Frozen: True
# Layer 64: transformer.h.5.attn.c_attn.weight, Frozen: True
# Layer 65: transformer.h.5.attn.c_attn.bias, Frozen: True
# Layer 66: transformer.h.5.attn.c_proj.weight, Frozen: True
# Layer 67: transformer.h.5.attn.c_proj.bias, Frozen: True
# Layer 68: transformer.h.5.ln_2.weight, Frozen: True
# Layer 69: transformer.h.5.ln_2.bias, Frozen: True
# Layer 70: transformer.h.5.mlp.c_fc.weight, Frozen: True
# Layer 71: transformer.h.5.mlp.c_fc.bias, Frozen: True
# Layer 72: transformer.h.5.mlp.c_proj.weight, Frozen: True
# Layer 73: transformer.h.5.mlp.c_proj.bias, Frozen: True
# Layer 74: transformer.h.6.ln_1.weight, Frozen: True
# Layer 75: transformer.h.6.ln_1.bias, Frozen: True
# Layer 76: transformer.h.6.attn.c_attn.weight, Frozen: True
# Layer 77: transformer.h.6.attn.c_attn.bias, Frozen: True
# Layer 78: transformer.h.6.attn.c_proj.weight, Frozen: True
# Layer 79: transformer.h.6.attn.c_proj.bias, Frozen: True
# Layer 80: transformer.h.6.ln_2.weight, Frozen: True
# Layer 81: transformer.h.6.ln_2.bias, Frozen: True
# Layer 82: transformer.h.6.mlp.c_fc.weight, Frozen: True
# Layer 83: transformer.h.6.mlp.c_fc.bias, Frozen: True
# Layer 84: transformer.h.6.mlp.c_proj.weight, Frozen: True
# Layer 85: transformer.h.6.mlp.c_proj.bias, Frozen: True
# Layer 86: transformer.h.7.ln_1.weight, Frozen: True
# Layer 87: transformer.h.7.ln_1.bias, Frozen: True
# Layer 88: transformer.h.7.attn.c_attn.weight, Frozen: True
# Layer 89: transformer.h.7.attn.c_attn.bias, Frozen: True
# Layer 90: transformer.h.7.attn.c_proj.weight, Frozen: True
# Layer 91: transformer.h.7.attn.c_proj.bias, Frozen: True
# Layer 92: transformer.h.7.ln_2.weight, Frozen: True
# Layer 93: transformer.h.7.ln_2.bias, Frozen: True
# Layer 94: transformer.h.7.mlp.c_fc.weight, Frozen: True
# Layer 95: transformer.h.7.mlp.c_fc.bias, Frozen: True
# Layer 96: transformer.h.7.mlp.c_proj.weight, Frozen: True
# Layer 97: transformer.h.7.mlp.c_proj.bias, Frozen: True
# Layer 98: transformer.h.8.ln_1.weight, Frozen: True
# Layer 99: transformer.h.8.ln_1.bias, Frozen: True
# Layer 100: transformer.h.8.attn.c_attn.weight, Frozen: True
# Layer 101: transformer.h.8.attn.c_attn.bias, Frozen: True
# Layer 102: transformer.h.8.attn.c_proj.weight, Frozen: True
# Layer 103: transformer.h.8.attn.c_proj.bias, Frozen: True
# Layer 104: transformer.h.8.ln_2.weight, Frozen: True
# Layer 105: transformer.h.8.ln_2.bias, Frozen: True
# Layer 106: transformer.h.8.mlp.c_fc.weight, Frozen: True
# Layer 107: transformer.h.8.mlp.c_fc.bias, Frozen: True
# Layer 108: transformer.h.8.mlp.c_proj.weight, Frozen: True
# Layer 109: transformer.h.8.mlp.c_proj.bias, Frozen: True
# Layer 110: transformer.h.9.ln_1.weight, Frozen: True
# Layer 111: transformer.h.9.ln_1.bias, Frozen: True
# Layer 112: transformer.h.9.attn.c_attn.weight, Frozen: True
# Layer 113: transformer.h.9.attn.c_attn.bias, Frozen: True
# Layer 114: transformer.h.9.attn.c_proj.weight, Frozen: True
# Layer 115: transformer.h.9.attn.c_proj.bias, Frozen: True
# Layer 116: transformer.h.9.ln_2.weight, Frozen: True
# Layer 117: transformer.h.9.ln_2.bias, Frozen: True
# Layer 118: transformer.h.9.mlp.c_fc.weight, Frozen: True
# Layer 119: transformer.h.9.mlp.c_fc.bias, Frozen: True
# Layer 120: transformer.h.9.mlp.c_proj.weight, Frozen: True
# Layer 121: transformer.h.9.mlp.c_proj.bias, Frozen: True
# Layer 122: transformer.h.10.ln_1.weight, Frozen: False
# Layer 123: transformer.h.10.ln_1.bias, Frozen: False
# Layer 124: transformer.h.10.attn.c_attn.weight, Frozen: False
# Layer 125: transformer.h.10.attn.c_attn.bias, Frozen: False
# Layer 126: transformer.h.10.attn.c_proj.weight, Frozen: False
# Layer 127: transformer.h.10.attn.c_proj.bias, Frozen: False
# Layer 128: transformer.h.10.ln_2.weight, Frozen: False
# Layer 129: transformer.h.10.ln_2.bias, Frozen: False
# Layer 130: transformer.h.10.mlp.c_fc.weight, Frozen: False
# Layer 131: transformer.h.10.mlp.c_fc.bias, Frozen: False
# Layer 132: transformer.h.10.mlp.c_proj.weight, Frozen: False
# Layer 133: transformer.h.10.mlp.c_proj.bias, Frozen: False
# Layer 134: transformer.h.11.ln_1.weight, Frozen: False
# Layer 135: transformer.h.11.ln_1.bias, Frozen: False
# Layer 136: transformer.h.11.attn.c_attn.weight, Frozen: False
# Layer 137: transformer.h.11.attn.c_attn.bias, Frozen: False
# Layer 138: transformer.h.11.attn.c_proj.weight, Frozen: False
# Layer 139: transformer.h.11.attn.c_proj.bias, Frozen: False
# Layer 140: transformer.h.11.ln_2.weight, Frozen: False
# Layer 141: transformer.h.11.ln_2.bias, Frozen: False
# Layer 142: transformer.h.11.mlp.c_fc.weight, Frozen: False
# Layer 143: transformer.h.11.mlp.c_fc.bias, Frozen: False
# Layer 144: transformer.h.11.mlp.c_proj.weight, Frozen: False
# Layer 145: transformer.h.11.mlp.c_proj.bias, Frozen: False
# Layer 146: transformer.ln_f.weight, Frozen: False
# Layer 147: transformer.ln_f.bias, Frozen: False
